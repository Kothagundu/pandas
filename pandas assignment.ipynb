# %%
import pandas as pd

# %%
df=pd.read_excel("C:\Users\subbu\OneDrive\Desktop\PETROL -ETHANOL BLENDED RESULTS.xlsx")
df
# Out:
#   Input In [2]
#     df=pd.read_excel("C:\Users\subbu\OneDrive\Desktop\PETROL -ETHANOL BLENDED RESULTS.xlsx")
#                                                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\subbu\Downloads\CarPrice_Assignment.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel(r"E:\python\1.xlsx")
df
# Out:
#            diesel     jatropha  wastecooking oil  b20 jatropha  \
# 0             NaN          NaN               NaN           NaN
# 1             NaN   389.105425         41.943255      0.107794
# 2       43.982763   744.303075         60.862294     -0.070563
# 3    -1961.468468  -812.550811        185.723699     -1.340094
# 4     -502.642021  1000.632434        122.415951      0.242300
# ...           ...          ...               ...           ...
# 1949          NaN          NaN               NaN           NaN
# 1950          NaN          NaN               NaN           NaN
# 1951          NaN          NaN               NaN           NaN
# 1952          NaN          NaN               NaN           NaN
# 1953          NaN          NaN               NaN           NaN
#
#       b20 waste cooking
# 0                   NaN
# 1             -9.274379
# 2            -39.350914
# 3              6.497454
# 4             15.780849
# ...                 ...
# 1949                NaN
# ...

# %%
df.shape
# Out:
# (1954, 5)

# %%
df.dtypes
# Out:
# diesel               float64
# jatropha             float64
# wastecooking oil     float64
# b20 jatropha         float64
# b20 waste cooking    float64
# dtype: object

# %%
df.count()
# Out:
# diesel               1822
# jatropha             1923
# wastecooking oil     1749
# b20 jatropha         1924
# b20 waste cooking    1750
# dtype: int64

# %%
df=df.drop_duplicates()
df.head()
# Out:
#         diesel     jatropha  wastecooking oil  b20 jatropha  b20 waste cooking
# 0          NaN          NaN               NaN           NaN                NaN
# 1          NaN   389.105425         41.943255      0.107794          -9.274379
# 2    43.982763   744.303075         60.862294     -0.070563         -39.350914
# 3 -1961.468468  -812.550811        185.723699     -1.340094           6.497454
# 4  -502.642021  1000.632434        122.415951      0.242300          15.780849

# %%
df=df.dropna()
df.count()
# Out:
# diesel               1748
# jatropha             1748
# wastecooking oil     1748
# b20 jatropha         1748
# b20 waste cooking    1748
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# diesel               0
# jatropha             0
# wastecooking oil     0
# b20 jatropha         0
# b20 waste cooking    0
# dtype: int64

# %%
import pandas as pd

# %%
df=pd.read_csv("E:\python\Banking Data.csv")
df
# Out:
#     S.No       Day Branch       City  FeMale  Male  Total Gender  \
# 0      1    Sunday      A  vijaywada     163   177           340
# 1      2    Monday      A  vijaywada     180   160           340
# 2      3   Tuesday      A  vijaywada     193   147           340
# 3      4  Wednsday      A  vijaywada     202   138           340
# 4      5  Thursday      A  vijaywada     145   195           340
# 5      6    Friday      A  vijaywada     212   128           340
# 6      7  Saturday      A  vijaywada     222   118           340
# 7      8    Sunday      B      vizag     189   143           332
# 8      9    Monday      B      vizag     195   137           332
# 9     10   Tuesday      B      vizag     201   131           332
# 10    11  Wednsday      B      vizag     189   143           332
# 11    12  Thursday      B      vizag     221   111           332
# 12    13    Friday      B      vizag     215   117           332
# ...

# %%
df['sum']=df['FEMale payment']+df['Male payment']
print(df)
# Out:
#     S.No       Day Branch       City  FeMale  Male  Total Gender  \
# 0      1    Sunday      A  vijaywada     163   177           340
# 1      2    Monday      A  vijaywada     180   160           340
# 2      3   Tuesday      A  vijaywada     193   147           340
# 3      4  Wednsday      A  vijaywada     202   138           340
# 4      5  Thursday      A  vijaywada     145   195           340
# 5      6    Friday      A  vijaywada     212   128           340
# 6      7  Saturday      A  vijaywada     222   118           340
# 7      8    Sunday      B      vizag     189   143           332
# 8      9    Monday      B      vizag     195   137           332
# 9     10   Tuesday      B      vizag     201   131           332
# 10    11  Wednsday      B      vizag     189   143           332
# 11    12  Thursday      B      vizag     221   111           332
# 12    13    Friday      B      vizag     215   117           332
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel("E:\python\Assignment-20220329T154039Z-001\Data Analysis Case Study Jun_2021.xlsx")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    860-79-0874      C  Naypyitaw        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    687-47-8271      A     Yangon        Normal    Male
# 4    283-26-5248      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  236-86-3015      C  Naypyitaw        Member    Male
# 996  192-98-7397      C  Naypyitaw        Normal    Male
# 997  279-62-1445      C  Naypyitaw        Member  Female
# 998  308-39-1707      A     Yangon        Normal  Female
# 999  784-21-9238      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  Day  \
# 0       Fashion accessories       99.30        10  49.6500  1042.6500    6
# 1    Electronic accessories       15.28         5   3.8200    80.2200    6
# ...

# %%
import numpy as np

# %%
gk=df[["Branch", "City"]].groupby(["Branch","City"])
gk.aggregate(np.sum)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(A, Yangon), (B, Mandalay), (C, Naypyitaw)]

# %%
#which branch is located in which city#

# %%
import pandas as pd

# %%
df=pd.read_excel("E:\python\Assignment-20220329T154039Z-001\Data Analysis Case Study Jun_2021.xlsx")
df[["Branch","City"]].groupby("City").Branch.unique()
# Out:
# City
# Mandalay     [B]
# Naypyitaw    [C]
# Yangon       [A]
# Name: Branch, dtype: object

# %%
#3.total sale amount

# %%
import pandas as pd

# %%
df=pd.read_excel("E:\python\Assignment-20220329T154039Z-001\Data Analysis Case Study Jun_2021.xlsx")

# %%
df[["Branch","Total"]].groupby("Branch").agg(["mean","sum","count"])
# Out:
#              Total
#               mean          sum count
# Branch
# A       312.354031  106200.3705   340
# B       319.872506  106197.6720   332
# C       337.099715  110568.7065   328

# %%
#what percentage was contributed by men and women

# %%
df=pd.read_excel("E:\python\Assignment-20220329T154039Z-001\Data Analysis Case Study Jun_2021.xlsx")
df[["gross margin percentage","Gender"]].groupby("Gender").agg(["mean","sum","count"])
# Out:
#        gross margin percentage
#                           mean          sum count
# Gender
# Female                4.761905  2385.714286   501
# Male                  4.761905  2376.190476   499

# %%
df=pd.read_excel("E:\python\Assignment-20220329T154039Z-001\Data Analysis Case Study Jun_2021.xlsx")
print([df.City.max()])
# Out:
# ['Yangon']

# %%
df=pd.read_excel("E:\python\Assignment-20220329T154039Z-001\Data Analysis Case Study Jun_2021.xlsx")
df[["gross income","City"]].groupby("City").max(["City"])
# Out:
#            gross income
# City
# Mandalay          48.69
# Naypyitaw         49.65
# Yangon            49.49

# %%
df[["gross income","City"]].groupby("City").min(["City"])
# Out:
#            gross income
# City
# Mandalay         0.8875
# Naypyitaw        0.5085
# Yangon           0.6045

# %%
df[["gross income","Gender"]].groupby("Gender").max(["Gender"])
# Out:
#         gross income
# Gender
# Female         49.65
# Male           49.49

# %%
df[["gross income","Gender"]].groupby("Gender").min(["Gender"])
# Out:
#         gross income
# Gender
# Female        0.6045
# Male          0.5085

# %%
gk=df[["Branch", "City","Day","Total"]].groupby(["Branch","City","Day","Total"])
gk.aggregate(np.sum)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df[["Tax 5%","City",]].groupby("City").max(["City"])
# Out:
#            Tax 5%
# City
# Mandalay    48.69
# Naypyitaw   49.65
# Yangon      49.49

# %%
df[["Tax 5%","City",]].groupby("City").min(["City"])
# Out:
#            Tax 5%
# City
# Mandalay   0.8875
# Naypyitaw  0.5085
# Yangon     0.6045

# %%
df[["Tax 5%","City",]].pivot ("City","Tax 5%").max(["City","Tax 5%"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <module>
# ----> 1 df[["Tax 5%","City",]].pivot ("City","Tax 5%").max(["City","Tax 5%"])
#
# File ~\lib\site-packages\pandas\core\frame.py:7870, in DataFrame.pivot(self, index, columns, values)
#    7865 @Substitution("")
#    7866 @Appender(_shared_docs["pivot"])
#    7867 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7868     from pandas.core.reshape.pivot import pivot
# -> 7870     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# ...
